# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
rng = np.random.default_rng()
x = [0] * 101
for t in range(1,101):
    x[t] = x[t-1] + rng.normal(0,1)
plt.title("Sample Path")
plt.xlabel("t")
plt.ylabel("x")
plt.plot(x)
plt.show()
